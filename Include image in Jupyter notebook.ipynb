# %% [markdown]
# Importing image in Jupyter Notebook. First make a folder name img and put all your image there. Then use the following codes to include the image in your Jupyter notebook. Be sure that you are in the same directory.
# The simplest method
# ![title](img/ring.jpg)

# %% [markdown]
# ![title](img/ring.png)

# %%
from IPython.display import Image
Image(filename = "img/ring.png",width=800,height=400)

# %%
# %%html
# <img src="img/ring.png",width=60,height=400>
# Out:
# <img src="img/ring.png",width=60,height=400>
